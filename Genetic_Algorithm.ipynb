# %%
import random
import string

# %%
TARGET_STRING = "HELLOGENETICALGORITHM"
POPULATION_SIZE = 1000
MUTATION_RATE = 0.01
MAX_GENERATIONS = 1000

# %%
def random_string(length=len(TARGET_STRING)):
    return ''.join(random.choice(string.ascii_uppercase) for _ in range(length))

# %%
# Compute how close a string is to the target string
def fitness(individual):
    # Count number of positions where the individuol strinq matches the target string
    return sum(1 for a, b in zip(individual, TARGET_STRING) if a==b)

# %%
# Select a parent string from the population, favoring fitter strings
def select_parent(population):
    # Select ond return one individual. from the population based on fitness weights
    return random.choices(population, weights=[fitness(ind) for ind in population], k=1)[0]

# %%
# Combine two strings into one
def crossover(parent1, parent2):
    # Randomly choose a split point
    split= random.randint(1, len(TARGET_STRING)-2)
    # Create a new string that's part one parent and part the other
    child = parent1[:split] + parent2[split:]
    return child

# %%
# Bloke a smolt random change to a string
def mutate(individual):
    # With a small chance, alter one character in the string
    if random.random() < MUTATION_RATE:
        # Pick a random position in the string
        position = random. randint(0, len(TARGET_STRING) - 1)
        # Pick a random uppercase character
        replacement = random.choice(string.ascii_uppercase)
        # Replace the character at the chosen position
        individual = individual[:position] + replacement + individual[position+1:]
    return individual

# %%
# The main evolution process
def evolve():
    # Create an initial random population of strings
    population = [random_string() for _ in range(POPULATION_SIZE)]
    # For a number of generations...
    for generation in range(MAX_GENERATIONS):
        # Print the best string in this generation
        print(f"Generation {generation + 1}: Best String: {max(population, key=fitness)}")
        
        # If we 've found the target string, stop
        if max(population, key=fitness) == TARGET_STRING:
            print("Target String reached!")
            break
            
        # Create a new generation of strings
        new_population = []
        for _ in range(POPULATION_SIZE):
            # select 2 parent strings
            parent1 = select_parent(population)
            parent2 = select_parent(population)
            # Create child string by combining the parents
            child = crossover(parent1, parent2)
            # Possibly mutate the child
            child = mutate(child)
            # Add the child to the new generation
            new_population.append(child)
            
        # Replace the old generation with new generation
        population = new_population

# %%
evolve()
# Out:
# Generation 1: Best String: HGLHBREOZQTOSPIHRJRHB
# Generation 2: Best String: HEFXOUTRITDJAGNCFIHYT
# Generation 3: Best String: HMYLXIXNEALCTNKHYYGDM
# Generation 4: Best String: COLNDGZNWTIGGQLQRIONV
# Generation 5: Best String: HEWHTGBNXTYBAQGMVTTSV
# Generation 6: Best String: HEYLXIXNEALCTNKHYIHRM
# Generation 7: Best String: HELANGRNEALCULZFCATSV
# Generation 8: Best String: HDELDGZNWTVEALPKRMTDM
# Generation 9: Best String: HESMFABAETVEALPURITHB
# Generation 10: Best String: HEFXOVFNWTILALPKRMTDM
# Generation 11: Best String: HILLZGBNETPCALAOSTOHJ
# Generation 12: Best String: HEFLUGBNNTZCAXGWBITHB
# Generation 13: Best String: HGLXOGCNETSCAAZORITDM
# Generation 14: Best String: HEFXOGENETFCALPOQITON
# Generation 121: Best String: HELLOGENETICALGORITKM
# Generation 122: Best String: HELLOGENETICALGORITEM
# Generation 123: Best String: HELLOGENETICALGORITKM
# Generation 124: Best String: HELLOGENETICALGORITHD
# Generation 125: Best String: HELLOGENETICALGORITEM
# Generation 126: Best String: HELLOGENETICALGORITHD
# Generation 127: Best String: HELLOGENETICALGORITHQ
# Generation 128: Best String: HELLOGENETICALGORITDM
# Generation 129: Best String: HELLOGENETICALGORITHD
# Generation 130: Best String: HELLOGENETICALGORITHD
# Generation 131: Best String: HELLOGENETICALGORITEM
# Generation 132: Best String: HELLOGENETICALGORITHC
# Generation 133: Best String: HELLOGENETICALGORITEM
# Generation 134: Best String: HELLOGENETICALGORITHB
# Generation 135: Best String: HELLOGENETICALGORITEM
# Generation 136: Best String: HELLOGENETICALGORITEM
# Generation 137: Best String: HELLOGENETICALGORITEM
# Generation 138: Best String: HELLOGENETICALGORITKM
# Generation 139: Best String: HELLOGENETICALGORITHD
# Generation 140: Best String: HELLOGENETICALGORITKM
# Generation 141: Best String: HELLOGENETICALGORITHD
# Generation 142: Best String: HELLOGENETICALGORITFM
# Generation 143: Best String: HELLOGENETICALGORITEM
# Generation 144: Best String: HELLOGENETICALGORITHD
# Generation 145: Best String: HELLOGENETICALGORITHD
# Generation 146: Best String: HELLOGENETICALGORITHD
# Generation 147: Best String: HELLOGENETICALGORITEM
# Generation 148: Best String: HELLOGENETICALGORITHD
# Generation 149: Best String: HELLOGENETICALGORITHD
# Generation 150: Best String: HELLOGENETICALGORITTM
# Generation 151: Best String: HELLOGENETICALGORITHQ
# Generation 152: Best String: HELLOGENETICALGORITEM
# Generation 153: Best String: HELLOGENETICALGORITEM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 evolve()
#
# Cell In[19], line 19, in evolve()
#      16 new_population = []
#      17 for _ in range(POPULATION_SIZE):
#      18     # select 2 parent strings
# ---> 19     parent1 = select_parent(population)
#      20     parent2 = select_parent(population)
#      21     # Create child string by combining the parents
#
# Cell In[8], line 4, in select_parent(population)
#       2 def select_parent(population):
#       3     # Select ond return one individual. from the population based on fitness weights
# ----> 4     return random.choices(population, weights=[fitness(ind) for ind in population], k=1)[0]
#
# Cell In[8], line 4, in <listcomp>(.0)
#       2 def select_parent(population):
#       3     # Select ond return one individual. from the population based on fitness weights
# ----> 4     return random.choices(population, weights=[fitness(ind) for ind in population], k=1)[0]
#
# Cell In[6], line 4, in fitness(individual)
#       2 def fitness(individual):
#       3     # Count number of posit ions where the indi viduol strinq matches the target string
# ----> 4     return sum(1 for a, b in zip(individual, TARGET_STRING) if a==b)
#
# Cell In[6], line 4, in <genexpr>(.0)
#       2 def fitness(individual):
#       3     # Count number of posit ions where the indi viduol strinq matches the target string
# ----> 4     return sum(1 for a, b in zip(individual, TARGET_STRING) if a==b)
#
# KeyboardInterrupt:
